# %%
# !pip install opencv-python

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
img = cv2.imread('dog_03.jpeg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (183, 275, 3)

# %%
plt.imshow(img)
plt.show()

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img)
cv2.waitKey(3000)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
#Changing ColorSpaces

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img_rgb.shape
# Out:
# (183, 275, 3)

# %%
plt.imshow(img_rgb)

# %%
img_gray  = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
img_gray.shape
# Out:
# (183, 275)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
plt.imshow(img_hsv)

# %%
#Image Resizing

# %%
img_rgb.shape
# Out:
# (183, 275, 3)

# %%
plt.imshow(img_rgb)

# %%
img_new = cv2.resize(img_rgb, (100,100))

# %%
img_new.shape
# Out:
# (100, 100, 3)

# %%
plt.imshow(img_new)

# %%
#Blur

# %%
img_blur = cv2.blur(img_rgb, (5,5))

# %%
img_blur
# Out:
# array([[[111,  97,  76],
#         [111,  97,  77],
#         [109,  96,  77],
#         ...,
#         [156, 153, 124],
#         [156, 151, 123],
#         [155, 150, 122]],
#
#        [[111,  97,  77],
#         [111,  97,  77],
#         [109,  96,  77],
#         ...,
#         [155, 152, 123],
#         [155, 151, 123],
#         [155, 149, 121]],
#
#        [[110,  96,  76],
#         [110,  96,  77],
#         [108,  95,  77],
#         ...,
#         [154, 151, 122],
#         [154, 150, 121],
#         [154, 148, 120]],
#
#        ...,
#
#        [[ 67,  77,  40],
#         [ 68,  78,  41],
#         [ 67,  78,  42],
#         ...,
#         [161, 172,  98],
#         [157, 168,  99],
#         [156, 166, 100]],
#
#        [[ 58,  68,  34],
#         [ 61,  71,  37],
#         [ 61,  71,  38],
#         ...,
#         [152, 163,  90],
#         [147, 157,  89],
#         [145, 155,  89]],
#
#        [[ 59,  68,  35],
#         [ 61,  71,  38],
#         [ 61,  71,  39],
# ...

# %%
plt.imshow(img_blur)

# %%
#Image Rotation

# %%
img_rgb.shape
# Out:
# (183, 275, 3)

# %%
rows, cols = img_rgb.shape[:-1]

# %%
M = cv2.getRotationMatrix2D((rows/2, cols/2), 10, 0.9)

# %%
i = cv2.warpAffine(img_rgb, M, (cols, rows))

# %%
plt.imshow(i)

# %%
#Image Translation

# %%
M = np.float32([[1,0.1,-50], [0, 1, -50]])

# %%
M
# Out:
# array([[  1. ,   0.1, -50. ],
#        [  0. ,   1. , -50. ]], dtype=float32)

# %%
i_t = cv2.warpAffine(img_rgb, M, (cols, rows))

# %%
plt.imshow(i_t)

# %%
#Edge Detection

# %%
ie = cv2.Canny(img_rgb, 50,50)

# %%
plt.imshow(ie)

# %%
#Get Video From Camera

# %%
import cv2

# %%
import cv2

cam = cv2.VideoCapture(0)


while True:
  ret, frame = cam.read()

  if ret == False:
    continue

  cv2_imshow("my image", frame)

  key_pressed = cv2.waitKey(1) & 0xFF
  if key_pressed == ord('q'):
    break

cam.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-94-ecb1082fcf86> in <cell line: 6>()
#       8
#       9   if ret == False:
# ---> 10     continue
#      11
#      12   cv2_imshow("my image", frame)
#
# KeyboardInterrupt:

# %%
# Face Detection

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = plt.imread('gpoto03.jpg')

# %%
img.shape
# Out:
# (408, 612, 3)

# %%
plt.imshow(img)

# %%
detector  = cv2.CascadeClassifier('haarcascade_frontalface_default03.xml')

# %%
all_faces = detector.detectMultiScale(img, 2, 9)

# %%
all_faces.shape
# Out:
# (2, 4)

# %%
x,y,w,h = all_faces[0]

# %%
img = cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0), 2)

# %%
plt.imshow(img)

# %%
for face in all_faces:
  x,y,w,h = face
  img = cv2.rectangle(img, (x,y), (x+w, y+h), (255,0,0), 2)

# %%
plt.imshow(img)

# %%
#Face Detection in Real Time

# %%
import cv2
import matplotlib.pyplot as plt

# %%
detector  = cv2.CascadeClassifier('haarcascade_frontalface_default03.xml')

# %%
cam = cv2.VideoCapture(0)

while True:
  ret, frame = cam.read()

  if ret == False:
    continue

  all_faces = detector.detectMultiScale(frame,1.5, 5)

  for face in all_faces:
    x,y,w,h = face
    frame = cv2.rectangle(frame, (x,y), (x+w, y+h), (0,0,255), 2)

  cv2_imshow(frame)

  key_pressed = cv2.waitKey(1) & 0xFF
  if key_pressed == ord('q'):
    break

cam.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-128-637ef3826435> in <cell line: 3>()
#       2
#       3 while True:
# ----> 4   ret, frame = cam.read()
#       5
#       6   if ret == False:
#
# KeyboardInterrupt:
