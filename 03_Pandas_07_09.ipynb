# %%
# !pip install pandas
# Out:
# ...
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\skme2\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\skme2\anaconda3\lib\site-packages)
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
# Out:
# C:\Users\skme2\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\skme2\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\skme2\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# Series

# %%
books = ['c', 'c++', 'html', 'css', 'python', 'java', 'javascript']

# %%
type(books)
# Out:
# list

# %%
ser = pd.Series(data=books)

# %%
ser
# Out:
# 0             c
# 1           c++
# 2          html
# 3           css
# 4        python
# 5          java
# 6    javascript
# dtype: object

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
ser[2]
# Out:
# 'html'

# %%
ser[5]
# Out:
# 'java'

# %%
ser[6]
# Out:
# 'javascript'

# %%
ser.index = ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
ser
# Out:
# a             c
# b           c++
# c          html
# d           css
# e        python
# f          java
# g    javascript
# dtype: object

# %%
ser['d']
# Out:
# 'css'

# %%
ser['e']
# Out:
# 'python'

# %%
ser[4]
# Out:
# 'python'

# %%
import numpy as np

# %%
arr = np.random.randint(10,100, size = (6,4))

# %%
arr
# Out:
# array([[71, 29, 91, 85],
#        [92, 35, 90, 64],
#        [24, 83, 13, 21],
#        [26, 88, 73, 96],
#        [93, 68, 99, 52],
#        [61, 97, 47, 36]])

# %%
arr.ndim
# Out:
# 2

# %%
df = pd.DataFrame(data=arr)

# %%
df
# Out:
#     0   1   2   3
# 0  71  29  91  85
# 1  92  35  90  64
# 2  24  83  13  21
# 3  26  88  73  96
# 4  93  68  99  52
# 5  61  97  47  36

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.ndim
# Out:
# 2

# %%
df[2]
# Out:
# 0    53
# 1    38
# 2    82
# 3    64
# 4    13
# 5    66
# Name: 2, dtype: int32

# %%
df
# Out:
#     0   1   2   3
# 0  90  98  53  31
# 1  19  26  38  25
# 2  59  84  82  76
# 3  40  41  64  89
# 4  79  10  13  56
# 5  94  29  66  20

# %%
type(df[0])
# Out:
# pandas.core.series.Series

# %%
type(df[3])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#     0   1   2   3
# 0  90  98  53  31
# 1  19  26  38  25
# 2  59  84  82  76
# 3  40  41  64  89
# 4  79  10  13  56
# 5  94  29  66  20

# %%
df
# Out:
#     0   1   2   3
# 0  90  98  53  31
# 1  19  26  38  25
# 2  59  84  82  76
# 3  40  41  64  89
# 4  79  10  13  56
# 5  94  29  66  20

# %%
df.columns = ['A', 'B', 'C', 'D']

# %%
df
# Out:
#     A   B   C   D
# 0  71  29  91  85
# 1  92  35  90  64
# 2  24  83  13  21
# 3  26  88  73  96
# 4  93  68  99  52
# 5  61  97  47  36

# %%
df['B']
# Out:
# 0    98
# 1    26
# 2    84
# 3    41
# 4    10
# 5    29
# Name: B, dtype: int32

# %%
df.shape
# Out:
# (6, 4)

# %%
df.size
# Out:
# 24

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.head(2)
# Out:
#     A   B   C   D
# 0  90  98  53  31
# 1  19  26  38  25

# %%
df.tail(n = 3)
# Out:
#     A   B   C   D
# 3  40  41  64  89
# 4  79  10  13  56
# 5  94  29  66  20

# %%
df.sample(n = 4)
# Out:
#     A   B   C   D
# 1  19  26  38  25
# 4  79  10  13  56
# 3  40  41  64  89
# 5  94  29  66  20

# %%
df
# Out:
#     A   B   C   D
# 0  90  98  53  31
# 1  19  26  38  25
# 2  59  84  82  76
# 3  40  41  64  89
# 4  79  10  13  56
# 5  94  29  66  20

# %%
df['B']
# Out:
# 0    98
# 1    26
# 2    84
# 3    41
# 4    10
# 5    29
# Name: B, dtype: int32

# %%
df['A']
# Out:
# 0    90
# 1    19
# 2    59
# 3    40
# 4    79
# 5    94
# Name: A, dtype: int32

# %%
df[['A', 'B']]
# Out:
#     A   B
# 0  90  98
# 1  19  26
# 2  59  84
# 3  40  41
# 4  79  10
# 5  94  29

# %%
df[['B', 'C']]
# Out:
#     B   C
# 0  98  53
# 1  26  38
# 2  84  82
# 3  41  64
# 4  10  13
# 5  29  66

# %%
df[['C', "A", 'D']]
# Out:
#     C   A   D
# 0  53  90  31
# 1  38  19  25
# 2  82  59  76
# 3  64  40  89
# 4  13  79  56
# 5  66  94  20

# %%
df
# Out:
#     A   B   C   D
# 0  90  98  53  31
# 1  19  26  38  25
# 2  59  84  82  76
# 3  40  41  64  89
# 4  79  10  13  56
# 5  94  29  66  20

# %%
df['E'] = 25

# %%
df
# Out:
#     A   B   C   D   E
# 0  71  29  91  85  25
# 1  92  35  90  64  25
# 2  24  83  13  21  25
# 3  26  88  73  96  25
# 4  93  68  99  52  25
# 5  61  97  47  36  25

# %%
df['A+C'] = df['A'] + df['C']

# %%
df
# Out:
#     A   B   C   D   E  A+C
# 0  71  29  91  85  25  162
# 1  92  35  90  64  25  182
# 2  24  83  13  21  25   37
# 3  26  88  73  96  25   99
# 4  93  68  99  52  25  192
# 5  61  97  47  36  25  108

# %%
df['F'] = 23*12

# %%
df
# Out:
#     A   B   C   D   E  A+C    F
# 0  71  29  91  85  25  162  276
# 1  92  35  90  64  25  182  276
# 2  24  83  13  21  25   37  276
# 3  26  88  73  96  25   99  276
# 4  93  68  99  52  25  192  276
# 5  61  97  47  36  25  108  276

# %%
df['F*B'] = df['F']*df['B']

# %%
df
# Out:
#     A   B   C   D   E  A+C    F    F*B
# 0  71  29  91  85  25  162  276   8004
# 1  92  35  90  64  25  182  276   9660
# 2  24  83  13  21  25   37  276  22908
# 3  26  88  73  96  25   99  276  24288
# 4  93  68  99  52  25  192  276  18768
# 5  61  97  47  36  25  108  276  26772

# %%
df
# Out:
#     A   B   C   D   E  A+C    F    F*B
# 0  71  29  91  85  25  162  276   8004
# 1  92  35  90  64  25  182  276   9660
# 2  24  83  13  21  25   37  276  22908
# 3  26  88  73  96  25   99  276  24288
# 4  93  68  99  52  25  192  276  18768
# 5  61  97  47  36  25  108  276  26772

# %%
df.drop('A', axis=1)
# Out:
#     B   C   D   E  A+C    F    F*B
# 0  98  53  31  25  143  276  27048
# 1  26  38  25  25   57  276   7176
# 2  84  82  76  25  141  276  23184
# 3  41  64  89  25  104  276  11316
# 4  10  13  56  25   92  276   2760
# 5  29  66  20  25  160  276   8004

# %%
df
# Out:
#     A   B   C   D   E  A+C    F    F*B
# 0  90  98  53  31  25  143  276  27048
# 1  19  26  38  25  25   57  276   7176
# 2  59  84  82  76  25  141  276  23184
# 3  40  41  64  89  25  104  276  11316
# 4  79  10  13  56  25   92  276   2760
# 5  94  29  66  20  25  160  276   8004

# %%
df.index = "p q r s t u".split()

# %%
df
# Out:
#     A   B   C   D   E  A+C    F    F*B
# 0  71  29  91  85  25  162  276   8004
# 1  92  35  90  64  25  182  276   9660
# 2  24  83  13  21  25   37  276  22908
# 3  26  88  73  96  25   99  276  24288
# 4  93  68  99  52  25  192  276  18768
# 5  61  97  47  36  25  108  276  26772

# %%
df.drop(labels='B', axis=1)
# Out:
#     A   C   D   E  A+C    F    F*B
# p  90  53  31  25  143  276  27048
# q  19  38  25  25   57  276   7176
# r  59  82  76  25  141  276  23184
# s  40  64  89  25  104  276  11316
# t  79  13  56  25   92  276   2760
# u  94  66  20  25  160  276   8004

# %%
df.drop(columns="E")
# Out:
#     A   B   C   D  A+C    F    F*B
# p  90  98  53  31  143  276  27048
# q  19  26  38  25   57  276   7176
# r  59  84  82  76  141  276  23184
# s  40  41  64  89  104  276  11316
# t  79  10  13  56   92  276   2760
# u  94  29  66  20  160  276   8004

# %%
df.drop(columns='F')
# Out:
#     A   B   C   D   E  A+C    F*B
# p  90  98  53  31  25  143  27048
# q  19  26  38  25  25   57   7176
# r  59  84  82  76  25  141  23184
# s  40  41  64  89  25  104  11316
# t  79  10  13  56  25   92   2760
# u  94  29  66  20  25  160   8004

# %%
df.drop('p')
# Out:
#     A   B   C   D   E  A+C    F    F*B
# q  19  26  38  25  25   57  276   7176
# r  59  84  82  76  25  141  276  23184
# s  40  41  64  89  25  104  276  11316
# t  79  10  13  56  25   92  276   2760
# u  94  29  66  20  25  160  276   8004

# %%
df.drop(labels='r')
# Out:
#     A   B   C   D   E  A+C    F    F*B
# p  90  98  53  31  25  143  276  27048
# q  19  26  38  25  25   57  276   7176
# s  40  41  64  89  25  104  276  11316
# t  79  10  13  56  25   92  276   2760
# u  94  29  66  20  25  160  276   8004

# %%
df.drop(index='p', inplace=True)

# %%
df
# Out:
#     A   B   C   D   E  A+C    F    F*B
# q  19  26  38  25  25   57  276   7176
# r  59  84  82  76  25  141  276  23184
# s  40  41  64  89  25  104  276  11316
# t  79  10  13  56  25   92  276   2760
# u  94  29  66  20  25  160  276   8004

# %%
df = df.drop(labels='A+C', axis=1)

# %%
df
# Out:
#     A   B   C   D   E    F    F*B
# q  19  26  38  25  25  276   7176
# r  59  84  82  76  25  276  23184
# s  40  41  64  89  25  276  11316
# t  79  10  13  56  25  276   2760
# u  94  29  66  20  25  276   8004

# %%
df.drop(labels=['F*B', 'D', 'B'], axis=1, inplace=True)

# %%
df
# Out:
#     A   C   E    F
# q  19  38  25  276
# r  59  82  25  276
# s  40  64  25  276
# t  79  13  25  276
# u  94  66  25  276

# %%
df = df.drop(labels=['r', 't', 's'])

# %%
df
# Out:
#     A   C   E    F
# q  19  38  25  276
# u  94  66  25  276

# %%
# Indexing/Extracting Data

# %%
df
# Out:
#     A   C   E    F
# q  19  38  25  276
# u  94  66  25  276

# %%
df
# Out:
#     A   C   E    F
# q  19  38  25  276
# u  94  66  25  276

# %%
df
# Out:
#     A   B   C   D   E  A+C    F    F*B
# 0  71  29  91  85  25  162  276   8004
# 1  92  35  90  64  25  182  276   9660
# 2  24  83  13  21  25   37  276  22908
# 3  26  88  73  96  25   99  276  24288
# 4  93  68  99  52  25  192  276  18768
# 5  61  97  47  36  25  108  276  26772

# %%
df.index = "p q r s t u".split()

# %%
df
# Out:
#     A   B   C   D   E  A+C    F    F*B
# p  71  29  91  85  25  162  276   8004
# q  92  35  90  64  25  182  276   9660
# r  24  83  13  21  25   37  276  22908
# s  26  88  73  96  25   99  276  24288
# t  93  68  99  52  25  192  276  18768
# u  61  97  47  36  25  108  276  26772

# %%
df
# Out:
#     A   B   C   D   E  A+C    F    F*B
# p  71  29  91  85  25  162  276   8004
# q  92  35  90  64  25  182  276   9660
# r  24  83  13  21  25   37  276  22908
# s  26  88  73  96  25   99  276  24288
# t  93  68  99  52  25  192  276  18768
# u  61  97  47  36  25  108  276  26772

# %%
df['B']
# Out:
# p    29
# q    35
# r    83
# s    88
# t    68
# u    97
# Name: B, dtype: int32

# %%
df.iloc[2]
# Out:
# A         24
# B         83
# C         13
# D         21
# E         25
# A+C       37
# F        276
# F*B    22908
# Name: r, dtype: int64

# %%
df.loc['r']
# Out:
# A         24
# B         83
# C         13
# D         21
# E         25
# A+C       37
# F        276
# F*B    22908
# Name: r, dtype: int64

# %%
df
# Out:
#     A   B   C   D   E  A+C    F    F*B
# p  71  29  91  85  25  162  276   8004
# q  92  35  90  64  25  182  276   9660
# r  24  83  13  21  25   37  276  22908
# s  26  88  73  96  25   99  276  24288
# t  93  68  99  52  25  192  276  18768
# u  61  97  47  36  25  108  276  26772

# %%
df.iloc[0]
# Out:
# A        71
# B        29
# C        91
# D        85
# E        25
# A+C     162
# F       276
# F*B    8004
# Name: p, dtype: int64

# %%
df
# Out:
#     A   B   C   D   E  A+C    F    F*B
# p  71  29  91  85  25  162  276   8004
# q  92  35  90  64  25  182  276   9660
# r  24  83  13  21  25   37  276  22908
# s  26  88  73  96  25   99  276  24288
# t  93  68  99  52  25  192  276  18768
# u  61  97  47  36  25  108  276  26772

# %%
df.iloc[1:3][['C','D']]
# Out:
#     C   D
# q  90  64
# r  13  21

# %%
df.iloc[2:5][['A','B']]
# Out:
#     A   B
# r  24  83
# s  26  88
# t  93  68

# %%
df.iloc[-2:][['F', 'F*B']]
# Out:
#      F    F*B
# t  276  18768
# u  276  26772

# %%
df.iloc[-2:, -2:]
# Out:
#      F    F*B
# t  276  18768
# u  276  26772

# %%
df.iloc[2:4,2:4]
# Out:
#     C   D
# r  13  21
# s  73  96

# %%
# Masking : boolean Indexing

# %%
df
# Out:
#     A   B   C   D   E  A+C    F    F*B
# p  71  29  91  85  25  162  276   8004
# q  92  35  90  64  25  182  276   9660
# r  24  83  13  21  25   37  276  22908
# s  26  88  73  96  25   99  276  24288
# t  93  68  99  52  25  192  276  18768
# u  61  97  47  36  25  108  276  26772

# %%
df
# Out:
#     A   B   C   D   E  A+C    F    F*B
# p  71  29  91  85  25  162  276   8004
# q  92  35  90  64  25  182  276   9660
# r  24  83  13  21  25   37  276  22908
# s  26  88  73  96  25   99  276  24288
# t  93  68  99  52  25  192  276  18768
# u  61  97  47  36  25  108  276  26772

# %%
mask = df>30

# %%
mask
# Out:
#        A      B      C      D      E   A+C     F   F*B
# p   True  False   True   True  False  True  True  True
# q   True   True   True   True  False  True  True  True
# r  False   True  False  False  False  True  True  True
# s  False   True   True   True  False  True  True  True
# t   True   True   True   True  False  True  True  True
# u   True   True   True   True  False  True  True  True

# %%
df[mask]
# Out:
#       A     B     C     D   E  A+C    F    F*B
# p  71.0   NaN  91.0  85.0 NaN  162  276   8004
# q  92.0  35.0  90.0  64.0 NaN  182  276   9660
# r   NaN  83.0   NaN   NaN NaN   37  276  22908
# s   NaN  88.0  73.0  96.0 NaN   99  276  24288
# t  93.0  68.0  99.0  52.0 NaN  192  276  18768
# u  61.0  97.0  47.0  36.0 NaN  108  276  26772

# %%
df[df>50]
# Out:
#       A     B     C     D   E    A+C    F    F*B
# p  71.0   NaN  91.0  85.0 NaN  162.0  276   8004
# q  92.0   NaN  90.0  64.0 NaN  182.0  276   9660
# r   NaN  83.0   NaN   NaN NaN    NaN  276  22908
# s   NaN  88.0  73.0  96.0 NaN   99.0  276  24288
# t  93.0  68.0  99.0  52.0 NaN  192.0  276  18768
# u  61.0  97.0   NaN   NaN NaN  108.0  276  26772

# %%
df[~(df>50)]
# Out:
#       A     B     C     D   E   A+C   F  F*B
# p   NaN  29.0   NaN   NaN  25   NaN NaN  NaN
# q   NaN  35.0   NaN   NaN  25   NaN NaN  NaN
# r  24.0   NaN  13.0  21.0  25  37.0 NaN  NaN
# s  26.0   NaN   NaN   NaN  25   NaN NaN  NaN
# t   NaN   NaN   NaN   NaN  25   NaN NaN  NaN
# u   NaN   NaN  47.0  36.0  25   NaN NaN  NaN

# %%
df[~(df['B']>40)]
# Out:
#     A   B   C   D   E  A+C    F   F*B
# p  71  29  91  85  25  162  276  8004
# q  92  35  90  64  25  182  276  9660

# %%
df[df['B']>50][['C', 'D']]
# Out:
#     C   D
# r  13  21
# s  73  96
# t  99  52
# u  47  36

# %%
df[df['A']>40][['F', 'B']]
# Out:
#      F   B
# p  276  29
# q  276  35
# t  276  68
# u  276  97

# %%
df[df['D']<50]
# Out:
#     A   B   C   D   E  A+C    F    F*B
# r  24  83  13  21  25   37  276  22908
# u  61  97  47  36  25  108  276  26772

# %%
df[~(df['D']<50)]
# Out:
#     A   B   C   D   E  A+C    F    F*B
# p  71  29  91  85  25  162  276   8004
# q  92  35  90  64  25  182  276   9660
# s  26  88  73  96  25   99  276  24288
# t  93  68  99  52  25  192  276  18768

# %%
df['A']>40
# Out:
# p     True
# q     True
# r    False
# s    False
# t     True
# u     True
# Name: A, dtype: bool

# %%
df['D']<50
# Out:
# p    False
# q    False
# r     True
# s    False
# t    False
# u     True
# Name: D, dtype: bool

# %%
df[(df['A']>40) & (df['D']<50)]
# Out:
#     A   B   C   D   E  A+C    F    F*B
# u  61  97  47  36  25  108  276  26772

# %%
df[~((df['A']>40) & (df['D']<50))]
# Out:
#     A   B   C   D   E  A+C    F    F*B
# p  71  29  91  85  25  162  276   8004
# q  92  35  90  64  25  182  276   9660
# r  24  83  13  21  25   37  276  22908
# s  26  88  73  96  25   99  276  24288
# t  93  68  99  52  25  192  276  18768

# %%
df
# Out:
#     A   B   C   D   E  A+C    F    F*B
# p  71  29  91  85  25  162  276   8004
# q  92  35  90  64  25  182  276   9660
# r  24  83  13  21  25   37  276  22908
# s  26  88  73  96  25   99  276  24288
# t  93  68  99  52  25  192  276  18768
# u  61  97  47  36  25  108  276  26772

# %%
arr = df.values

# %%
arr
# Out:
# array([[   71,    29,    91,    85,    25,   162,   276,  8004],
#        [   92,    35,    90,    64,    25,   182,   276,  9660],
#        [   24,    83,    13,    21,    25,    37,   276, 22908],
#        [   26,    88,    73,    96,    25,    99,   276, 24288],
#        [   93,    68,    99,    52,    25,   192,   276, 18768],
#        [   61,    97,    47,    36,    25,   108,   276, 26772]],
#       dtype=int64)

# %%
# Iris dataSet

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 0CC1-C20F
#
#  Directory of C:\Users\skme2\Downloads
#
# 07-09-2024  13:12    <DIR>          .
# 28-08-2024  09:30    <DIR>          ..
# 07-09-2024  11:58    <DIR>          .ipynb_checkpoints
# 01-06-2024  17:40               346 01_06_02.sql
# 01-06-2024  20:07               347 01_06_02_practice.sql
# 01-06-2024  16:43             8,550 01_06_window.sql
# 06-11-2023  11:20             2,633 01_11_sql_practice.sql
# 30-08-2024  08:26            15,553 01_inheritance_polymorphism_30_08.ipynb
# 07-09-2024  10:09            10,656 01_Text_Gen_project2_07_09.ipynb
# 03-05-2024  20:46         3,932,766 02_05_open_cv.ipynb
# 30-08-2024  11:08            58,925 02_Intermediate_python_30_08.ipynb
# 07-09-2024  11:58            74,959 02_numpy_07_09.ipynb
# 02-11-2022  15:49           410,816 0211resume.pdf
# 03-05-2024  20:45             4,167 03_05_cv2.ipynb
# 03-05-2024  19:04               576 03_05_open_cv.ipynb
# ...

# %%
df = pd.read_csv("iris07_09.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(n = 2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
df.tail(n = 3)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.sample(n = 4)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 121           5.6          2.8           4.9          2.0  virginica
# 132           6.4          2.8           5.6          2.2  virginica
# 31            5.4          3.4           1.5          0.4     setosa
# 20            5.4          3.4           1.7          0.2     setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.size
# Out:
# 750

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.species.nunique()
# Out:
# 3

# %%
df[df.species == 'setosa'].shape
# Out:
# (50, 5)

# %%
df.species.value_counts()['versicolor']
# Out:
# 50

# %%
df['petal_length'].min()
# Out:
# 1.0

# %%
df.petal_width.max()
# Out:
# 2.5

# %%
df.sepal_length.sum()
# Out:
# 876.5

# %%
df['sepal_width'].mean()
# Out:
# 3.0540000000000003

# %%
# Sorting

# %%
df.sort_values(by=['sepal_length'])
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 13            4.3          3.0           1.1          0.1     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 41            4.5          2.3           1.3          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 131           7.9          3.8           6.4          2.0  virginica
#
# [150 rows x 5 columns]

# %%
df.sort_values(by='petal_length', ascending=False, inplace=True)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 118           7.7          2.6           6.9          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# ..            ...          ...           ...          ...        ...
# 36            5.5          3.5           1.3          0.2     setosa
# 35            5.0          3.2           1.2          0.2     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 22            4.6          3.6           1.0          0.2     setosa
#
# [150 rows x 5 columns]

# %%
df = df.sort_values(by=['sepal_length', 'sepal_width'], ascending=[False, True])

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 131           7.9          3.8           6.4          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# ..            ...          ...           ...          ...        ...
# 41            4.5          2.3           1.3          0.3     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 38            4.4          3.0           1.3          0.2     setosa
# 42            4.4          3.2           1.3          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
#
# [150 rows x 5 columns]

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.species.apply(len)
# Out:
# 0      6
# 1      6
# 2      6
# 3      6
# 4      6
#       ..
# 145    9
# 146    9
# 147    9
# 148    9
# 149    9
# Name: species, Length: 150, dtype: int64

# %%
df.apply(lambda x:x+x)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width             species
# 0            10.2          7.0           2.8          0.4        setosasetosa
# 1             9.8          6.0           2.8          0.4        setosasetosa
# 2             9.4          6.4           2.6          0.4        setosasetosa
# 3             9.2          6.2           3.0          0.4        setosasetosa
# 4            10.0          7.2           2.8          0.4        setosasetosa
# ..            ...          ...           ...          ...                 ...
# 145          13.4          6.0          10.4          4.6  virginicavirginica
# 146          12.6          5.0          10.0          3.8  virginicavirginica
# 147          13.0          6.0          10.4          4.0  virginicavirginica
# 148          12.4          6.8          10.8          4.6  virginicavirginica
# 149          11.8          6.0          10.2          3.6  virginicavirginica
#
# [150 rows x 5 columns]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Grouping Data Together

# %%
df.agg('min')
# Out:
# sepal_length       4.3
# sepal_width        2.0
# petal_length       1.0
# petal_width        0.1
# species         setosa
# dtype: object

# %%
df.aggregate('min')
# Out:
# sepal_length       4.3
# sepal_width        2.0
# petal_length       1.0
# petal_width        0.1
# species         setosa
# dtype: object

# %%
df.aggregate(['min', 'max', 'mean', 'median'])
# Out:
# <ipython-input-339-ffcb6e11e7e8>:1: FutureWarning: ['species'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.aggregate(['min', 'max', 'mean', 'median'])
#         sepal_length  sepal_width  petal_length  petal_width    species
# min         4.300000        2.000      1.000000     0.100000     setosa
# max         7.900000        4.400      6.900000     2.500000  virginica
# mean        5.843333        3.054      3.758667     1.198667        NaN
# median      5.800000        3.000      4.350000     1.300000        NaN

# %%
g_obj = df.groupby(by='species')

# %%
g_obj

# %%
g_obj.min()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               4.3          2.3           1.0          0.1
# versicolor           4.9          2.0           3.0          1.0
# virginica            4.9          2.2           4.5          1.4

# %%
g_obj.max()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.8          4.4           1.9          0.6
# versicolor           7.0          3.4           5.1          1.8
# virginica            7.9          3.8           6.9          2.5

# %%
g_obj.sum()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             250.3        170.9          73.2         12.2
# versicolor         296.8        138.5         213.0         66.3
# virginica          329.4        148.7         277.6        101.3

# %%
g_obj.aggregate(['min', 'max', 'sum', 'mean', 'median']).T
# Out:
# species               setosa  versicolor  virginica
# sepal_length min       4.300       4.900      4.900
#              max       5.800       7.000      7.900
#              sum     250.300     296.800    329.400
#              mean      5.006       5.936      6.588
#              median    5.000       5.900      6.500
# sepal_width  min       2.300       2.000      2.200
#              max       4.400       3.400      3.800
#              sum     170.900     138.500    148.700
#              mean      3.418       2.770      2.974
#              median    3.400       2.800      3.000
# petal_length min       1.000       3.000      4.500
#              max       1.900       5.100      6.900
#              sum      73.200     213.000    277.600
#              mean      1.464       4.260      5.552
#              median    1.500       4.350      5.550
# petal_width  min       0.100       1.000      1.400
#              max       0.600       1.800      2.500
# ...

# %%
g_obj.describe().T
# Out:
# species                setosa  versicolor  virginica
# sepal_length count  50.000000   50.000000  50.000000
#              mean    5.006000    5.936000   6.588000
#              std     0.352490    0.516171   0.635880
#              min     4.300000    4.900000   4.900000
#              25%     4.800000    5.600000   6.225000
#              50%     5.000000    5.900000   6.500000
#              75%     5.200000    6.300000   6.900000
#              max     5.800000    7.000000   7.900000
# sepal_width  count  50.000000   50.000000  50.000000
#              mean    3.418000    2.770000   2.974000
#              std     0.381024    0.313798   0.322497
#              min     2.300000    2.000000   2.200000
#              25%     3.125000    2.525000   2.800000
#              50%     3.400000    2.800000   3.000000
#              75%     3.675000    3.000000   3.175000
#              max     4.400000    3.400000   3.800000
# petal_length count  50.000000   50.000000  50.000000
# ...

# %%
g_obj.count()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa                50           50            50           50
# versicolor            50           50            50           50
# virginica             50           50            50           50

# %%
g_obj.min()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               4.3          2.3           1.0          0.1
# versicolor           4.9          2.0           3.0          1.0
# virginica            4.9          2.2           4.5          1.4

# %%
df[df.species == 'virginica']['petal_width'].min()
# Out:
# 1.4

# %%
g_obj.sum()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             250.3        170.9          73.2         12.2
# versicolor         296.8        138.5         213.0         66.3
# virginica          329.4        148.7         277.6        101.3

# %%
# Handling missing Data
# dropna
# fillna

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
nan_idx = np.random.randint(0,150,20)

# %%
nan_idx
# Out:
# array([146,  98, 104,  71, 121,  14, 126, 128,  53,  69, 148,  21, 110,
#         60,  93,  88,   8,  53, 100,  14])

# %%
df.sepal_width[nan_idx] = np.nan
# Out:
# <ipython-input-379-7d55a73f8176>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sepal_width[nan_idx] = np.nan

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          NaN           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          NaN           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
nan_index = np.random.randint(0,140,15)

# %%
df['petal_length'][nan_index] = np.nan
# Out:
# <ipython-input-384-257e916c6fae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['petal_length'][nan_index] = np.nan

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           NaN          0.2     setosa
# 4             5.0          3.6           NaN          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          NaN           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          NaN           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal_length     0
# sepal_width     18
# petal_length    13
# petal_width      0
# species          0
# dtype: int64

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           NaN          0.2     setosa
# 4             5.0          3.6           NaN          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          NaN           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          NaN           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.dropna(axis=1)
# Out:
#      sepal_length  petal_width    species
# 0             5.1          0.2     setosa
# 1             4.9          0.2     setosa
# 2             4.7          0.2     setosa
# 3             4.6          0.2     setosa
# 4             5.0          0.2     setosa
# ..            ...          ...        ...
# 145           6.7          2.3  virginica
# 146           6.3          1.9  virginica
# 147           6.5          2.0  virginica
# 148           6.2          2.3  virginica
# 149           5.9          1.8  virginica
#
# [150 rows x 3 columns]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           NaN          0.2     setosa
# 4             5.0          3.6           NaN          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          NaN           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          NaN           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.fillna(value="sanjay")
# Out:
#      sepal_length sepal_width petal_length  petal_width    species
# 0             5.1         3.5          1.4          0.2     setosa
# 1             4.9         3.0          1.4          0.2     setosa
# 2             4.7         3.2          1.3          0.2     setosa
# 3             4.6         3.1       sanjay          0.2     setosa
# 4             5.0         3.6       sanjay          0.2     setosa
# ..            ...         ...          ...          ...        ...
# 145           6.7         3.0          5.2          2.3  virginica
# 146           6.3      sanjay          5.0          1.9  virginica
# 147           6.5         3.0          5.2          2.0  virginica
# 148           6.2      sanjay          5.4          2.3  virginica
# 149           5.9         3.0          5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
np.round(df.petal_length.mean(),1)
# Out:
# 3.8

# %%
df['petal_length'].fillna(value=np.round(df.petal_length.mean(),1), inplace=True)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           3.8          0.2     setosa
# 4             5.0          3.6           3.8          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          NaN           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          NaN           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# sepal_length     0
# sepal_width     18
# petal_length     0
# petal_width      0
# species          0
# dtype: int64

# %%
df.sepal_width.fillna(value=4.5, inplace=True)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           3.8          0.2     setosa
# 4             5.0          3.6           3.8          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          4.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          4.5           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           3.8          0.2     setosa
# 4             5.0          3.6           3.8          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          4.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          4.5           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Concat/merging data Frames

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           3.8          0.2     setosa
# 4             5.0          3.6           3.8          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          4.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          4.5           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
new_df = pd.DataFrame(np.random.randint(0,7, size = (10,4)))

# %%
new_df
# Out:
#    0  1  2  3
# 0  0  4  6  3
# 1  5  6  1  5
# 2  5  2  5  4
# 3  6  4  1  3
# 4  2  1  6  4
# 5  3  3  0  4
# 6  2  6  3  2
# 7  6  3  1  2
# 8  6  5  1  1
# 9  6  0  4  3

# %%
new_df["species"] = 'tetrapack'

# %%
new_df
# Out:
#    0  1  2  3    species
# 0  0  4  6  3  tetrapack
# 1  5  6  1  5  tetrapack
# 2  5  2  5  4  tetrapack
# 3  6  4  1  3  tetrapack
# 4  2  1  6  4  tetrapack
# 5  3  3  0  4  tetrapack
# 6  2  6  3  2  tetrapack
# 7  6  3  1  2  tetrapack
# 8  6  5  1  1  tetrapack
# 9  6  0  4  3  tetrapack

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
new_df.columns = df.columns

# %%
new_df
# Out:
#    sepal_length  sepal_width  petal_length  petal_width    species
# 0             0            4             6            3  tetrapack
# 1             5            6             1            5  tetrapack
# 2             5            2             5            4  tetrapack
# 3             6            4             1            3  tetrapack
# 4             2            1             6            4  tetrapack
# 5             3            3             0            4  tetrapack
# 6             2            6             3            2  tetrapack
# 7             6            3             1            2  tetrapack
# 8             6            5             1            1  tetrapack
# 9             6            0             4            3  tetrapack

# %%
v_concat = pd.concat((df,new_df))

# %%
v_concat.shape
# Out:
# (160, 5)

# %%
h_concat = pd.concat([df, new_df], axis=1)

# %%
h_concat.shape
# Out:
# (150, 10)

# %%
h_concat.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  sepal_length  \
# 0           5.1          3.5           1.4          0.2  setosa           0.0
# 1           4.9          3.0           1.4          0.2  setosa           5.0
# 2           4.7          3.2           1.3          0.2  setosa           5.0
# 3           4.6          3.1           3.8          0.2  setosa           6.0
# 4           5.0          3.6           3.8          0.2  setosa           2.0
#
#    sepal_width  petal_length  petal_width    species
# 0          4.0           6.0          3.0  tetrapack
# 1          6.0           1.0          5.0  tetrapack
# 2          2.0           5.0          4.0  tetrapack
# 3          4.0           1.0          3.0  tetrapack
# 4          1.0           6.0          4.0  tetrapack

# %%
# merging Data Frames

# %%
df1 = pd.DataFrame({
    'S_name' : ['Mohit', 'Jatin', 'Prateek', 'Mohit'],
    'CGPA' : [2,4,5,3]
})

# %%
df1
# Out:
#     S_name  CGPA
# 0    Mohit     2
# 1    Jatin     4
# 2  Prateek     5
# 3    Mohit     3

# %%
df2 = pd.DataFrame({
    'T_name' : ['Mohit', 'Jatin', 'Prateek', 'Mohit'],
    'CGPA' : [3,6,8,9]
})

# %%
df1
# Out:
#     S_name  CGPA
# 0    Mohit     2
# 1    Jatin     4
# 2  Prateek     5
# 3    Mohit     3

# %%
df2
# Out:
#     T_name  CGPA
# 0    Mohit     3
# 1    Jatin     6
# 2  Prateek     8
# 3    Mohit     9

# %%
df1.merge(right=df2, on='CGPA')
# Out:
#   S_name  CGPA T_name
# 0  Mohit     3  Mohit

# %%
df1.merge(right=df2, on='CGPA', how = "inner")
# Out:
#   S_name  CGPA T_name
# 0  Mohit     3  Mohit

# %%
df1.merge(right=df2, on='CGPA', how = "left")
# Out:
#     S_name  CGPA T_name
# 0    Mohit     2    NaN
# 1    Jatin     4    NaN
# 2  Prateek     5    NaN
# 3    Mohit     3  Mohit

# %%
df1.merge(right=df2, on='CGPA', how = "right")
# Out:
#   S_name  CGPA   T_name
# 0  Mohit     3    Mohit
# 1    NaN     6    Jatin
# 2    NaN     8  Prateek
# 3    NaN     9    Mohit

# %%
df1.merge(right=df2, on='CGPA', how = "outer")
# Out:
#     S_name  CGPA   T_name
# 0    Mohit     2      NaN
# 1    Jatin     4      NaN
# 2  Prateek     5      NaN
# 3    Mohit     3    Mohit
# 4      NaN     6    Jatin
# 5      NaN     8  Prateek
# 6      NaN     9    Mohit

# %%
df1.merge(right=df2, how = "cross")
# Out:
#      S_name  CGPA_x   T_name  CGPA_y
# 0     Mohit       2    Mohit       3
# 1     Mohit       2    Jatin       6
# 2     Mohit       2  Prateek       8
# 3     Mohit       2    Mohit       9
# 4     Jatin       4    Mohit       3
# 5     Jatin       4    Jatin       6
# 6     Jatin       4  Prateek       8
# 7     Jatin       4    Mohit       9
# 8   Prateek       5    Mohit       3
# 9   Prateek       5    Jatin       6
# 10  Prateek       5  Prateek       8
# 11  Prateek       5    Mohit       9
# 12    Mohit       3    Mohit       3
# 13    Mohit       3    Jatin       6
# 14    Mohit       3  Prateek       8
# 15    Mohit       3    Mohit       9

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           3.8          0.2     setosa
# 4             5.0          3.6           3.8          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          4.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          4.5           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           3.8          0.2     setosa
# 4             5.0          3.6           3.8          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          4.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          4.5           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
v_concat.to_csv("my_07_09_data.csv", index=False)

# %%
v_concat.to_excel("updated_0709.xlsx",sheet_name="P_done" ,index=False)
# Out:
# <ipython-input-464-3e25ee0f03d0>:1: UserWarning: Pandas requires version '1.4.3' or newer of 'xlsxwriter' (version '1.3.8' currently installed).
#   v_concat.to_excel("updated_0709.xlsx",sheet_name="P_done" ,index=False)

# %%
df_excel = pd.read_excel("updated_0709.xlsx")

# %%
df_excel
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           3.8          0.2     setosa
# 4             5.0          3.6           3.8          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 155           3.0          3.0           0.0          4.0  tetrapack
# 156           2.0          6.0           3.0          2.0  tetrapack
# 157           6.0          3.0           1.0          2.0  tetrapack
# 158           6.0          5.0           1.0          1.0  tetrapack
# 159           6.0          0.0           4.0          3.0  tetrapack
#
# [160 rows x 5 columns]
