# %%
print()

# %%
#This is a commant

# %%
# I am revising my python

# %%
# this will not be executed

# %%
print("Hello Students")
# Out:
# Hello Students

# %%
print("Python is fun")
# Out:
# Python is fun

# %%
print("Ml is easy")
# Out:
# Ml is easy

# %%
print("Deep learning is very good")
# Out:
# Deep learning is very good

# %%
print("data", 20, True, False)
# Out:
# data 20 True False

# %%
print(150,30,80,"Powerbi")
# Out:
# 150 30 80 Powerbi

# %% [markdown]
# # Variables: a variable is a placeholder for storing values or data
# # Identifier : identifier is the name given to entities : like class, function, and variables etc.
# # rules:
# * it can be a combination of lowercase, uppercase, digits, and an underscore
# * it can not start with digits
# * inbuilt keywords are never used
#
# # type()

# %%
p = 50

# %%
print(p)
# Out:
# 50

# %%
abc1 = 60

# %%
print(abc1)
# Out:
# 60

# %%
2abc = 20
# Out:
#   File "<ipython-input-17-7c57261a6249>", line 1
#     2abc = 20
#      ^
# SyntaxError: invalid syntax

# %%
type(abc1)
# Out:
# int

# %%
#Location of a variable

# %%
id(abc1)
# Out:
# 140731961126544

# %%
m = 100

# %%
type(m)
# Out:
# int

# %%
print(m)
# Out:
# 100

# %%
id(m)
# Out:
# 140731961127824

# %%
# Python is a dynamic typed language
# Same variables can take values of differnet data types

# %%
k = 259

# %%
print(k)
# Out:
# 259

# %%
type(k)
# Out:
# int

# %%
id(k)
# Out:
# 1567255183536

# %%
k = "Python is very easy"

# %%
type(k)
# Out:
# str

# %%
id(k)
# Out:
# 1567168134240

# %% [markdown]
# # Basic DataTypes:
# * int
# * float
# * string
# * complex
# * Boolean
# * None

# %%
h = 10

# %%
print(h)
# Out:
# 10

# %%
type(h)
# Out:
# int

# %%
print(type(h))
# Out:
# <class 'int'>

# %%
b = 12.6

# %%
type(b)
# Out:
# float

# %%
print(type(b))
# Out:
# <class 'float'>

# %%
d = True

# %%
a = False

# %%
type(d)
# Out:
# bool

# %%
type(a)
# Out:
# bool

# %%
e = 5+6j

# %%
type(e)
# Out:
# complex

# %%
e.imag
# Out:
# 6.0

# %%
e.real
# Out:
# 5.0

# %%
e.conjugate()
# Out:
# (5-6j)

# %%
a = "python is fun"

# %%
type(a)
# Out:
# str

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
w = None

# %%
type(w)
# Out:
# NoneType

# %%
print(type(w))
# Out:
# <class 'NoneType'>

# %%
#input : when we need to take input from user : it string data type

# %%
input()
# Out:
# data science
# 'data science'

# %%
m = input("Enter Your Message : ")
# Out:
# Enter Your Message : nlp is important

# %%
m
# Out:
# 'nlp is important'

# %%
type(m)
# Out:
# str

# %%
name = input("Enter Your name : ")
# Out:
# Enter Your name : Krishna

# %%
name
# Out:
# 'Krishna'

# %%
type(name)
# Out:
# str

# %%
k_age = input("Enter Your Age : ")
# Out:
# Enter Your Age : 35

# %%
name
# Out:
# 'Krishna'

# %%
k_age
# Out:
# '35'

# %%
type(name)
# Out:
# str

# %%
type(k_age)
# Out:
# str

# %%
# typecasting : converting one data type into another data type

# %%
num = "147"

# %%
type(num)
# Out:
# str

# %%
b = int(num)

# %%
b
# Out:
# 147

# %%
type(b)
# Out:
# int

# %%
f = float(b)

# %%
f
# Out:
# 147.0

# %%
type(f)
# Out:
# float

# %%
p = "456"

# %%
p
# Out:
# '456'

# %%
type(p)
# Out:
# str

# %%
p = int(p)

# %%
p
# Out:
# 456

# %%
type(p)
# Out:
# int

# %%
p = float(p)

# %%
p
# Out:
# 456.0

# %%
type(p)
# Out:
# float

# %%
p = complex(p)

# %%
p
# Out:
# (456+0j)

# %%
type(p)
# Out:
# complex

# %%
p = str(p)

# %%
p
# Out:
# '(456+0j)'

# %%
type(p)
# Out:
# str

# %%
age = int(input("Enter Your age : "))
# Out:
# Enter Your age : 25

# %%
age
# Out:
# 25

# %%
type(age)
# Out:
# int

# %% [markdown]
# # Python Statements :
# * Singleline statements
# * Multiline statements

# %%
# Singleline statments

# %%
h = 12

# %%
a = "ml is very good"

# %%
z = "sql is very important"

# %%
# multiple line statements"

# %%
w = (1+2+3+
    4+5+6+
    7+8+9+
    2)

# %%
w
# Out:
# 47

# %%
q = 1+2+3+\
    4+5+6+\
    7+8+9

# %%
q
# Out:
# 45

# %%
# Output Formatting

# %%
a = 10

# %%
b = 20
c = 30

# %%
print("The value of a is {} and b is {}".format(a, b))
# Out:
# The value of a is 10 and b is 20

# %%
print("The value of a is {} and b is {} and c is {}".format(a, b, c))
# Out:
# The value of a is 10 and b is 20 and c is 30

# %%
print("The value of a is {} and b is {} and c is {}".format(c,a,b))
# Out:
# The value of a is 30 and b is 10 and c is 20

# %%
print("The value of a is {1} and b is {0} and c is {2}".format(a, b, c))
# Out:
# The value of a is 20 and b is 10 and c is 30

# %%
name = "Sanjay"

# %%
greet = "Good Morning"

# %%
print("Hello {} and {}".format(name, greet))
# Out:
# Hello Sanjay and Good Morning

# %%
print("Hello {g} and {n}".format(n = name, g = greet))
# Out:
# Hello Good Morning and Sanjay

# %%
print("Hello {n} and {g}".format(n = name, g = greet))
# Out:
# Hello Sanjay and Good Morning

# %%
# f-string

# %%
print(f"The value of a is {a} and b is {b} and c is {c}")
# Out:
# The value of a is 10 and b is 20 and c is 30

# %%
print(f"Hello hi {name} and {greet}")
# Out:
# Hello hi Sanjay and Good Morning
