# %%
#inbuilt Modules

# %%
import math

# %%
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc']

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
math.factorial(5)
# Out:
# 120

# %%
math.ceil(2.3)
# Out:
# 3

# %%
# random Module

# %%
import random

# %%
random.randint(1,10)
# Out:
# 2

# %%
round(random.random()*50) + 10
# Out:
# 26

# %%
import os

# %%
print(dir(os))
# Out:
# ['DirEntry', 'F_OK', 'MutableMapping', 'O_APPEND', 'O_BINARY', 'O_CREAT', 'O_EXCL', 'O_NOINHERIT', 'O_RANDOM', 'O_RDONLY', 'O_RDWR', 'O_SEQUENTIAL', 'O_SHORT_LIVED', 'O_TEMPORARY', 'O_TEXT', 'O_TRUNC', 'O_WRONLY', 'P_DETACH', 'P_NOWAIT', 'P_NOWAITO', 'P_OVERLAY', 'P_WAIT', 'PathLike', 'R_OK', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'TMP_MAX', 'W_OK', 'X_OK', '_AddedDllDirectory', '_Environ', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_check_methods', '_execvpe', '_exists', '_exit', '_fspath', '_get_exports_list', '_putenv', '_unsetenv', '_wrap_close', 'abc', 'abort', 'access', 'add_dll_directory', 'altsep', 'chdir', 'chmod', 'close', 'closerange', 'cpu_count', 'curdir', 'defpath', 'device_encoding', 'devnull', 'dup', 'dup2', 'environ', 'error', 'execl', 'execle', 'execlp', 'execlpe', 'execv', 'execve', 'execvp', 'execvpe', 'extsep', 'fdopen', 'fsdecode', 'fsencode', 'fspath', 'fstat', 'fsync', 'ftruncate', 'get_ex
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\skme2\\Downloads'

# %%
os.mkdir("zepto")

# %%
os.remove('blinkit29.txt')

# %%
os.removedirs('zepto/')

# %%
os.rename('zomato29.txt', "invesco.txt")

# %%
# sys

# %%
import sys

# %%
sys.version
# Out:
# '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]'

# %%
print(dir(sys))
# Out:
# ['__breakpointhook__', '__displayhook__', '__doc__', '__excepthook__', '__interactivehook__', '__loader__', '__name__', '__package__', '__spec__', '__stderr__', '__stdin__', '__stdout__', '__unraisablehook__', '_base_executable', '_clear_type_cache', '_current_frames', '_debugmallocstats', '_enablelegacywindowsfsencoding', '_framework', '_getframe', '_git', '_home', '_xoptions', 'addaudithook', 'api_version', 'argv', 'audit', 'base_exec_prefix', 'base_prefix', 'breakpointhook', 'builtin_module_names', 'byteorder', 'call_tracing', 'callstats', 'copyright', 'displayhook', 'dllhandle', 'dont_write_bytecode', 'exc_info', 'excepthook', 'exec_prefix', 'executable', 'exit', 'flags', 'float_info', 'float_repr_style', 'get_asyncgen_hooks', 'get_coroutine_origin_tracking_depth', 'getallocatedblocks', 'getcheckinterval', 'getdefaultencoding', 'getfilesystemencodeerrors', 'getfilesystemencoding', 'getprofile', 'getrecursionlimit', 'getrefcount', 'getsizeof', 'getswitchinterval', 'gettrace', 'get
# ...

# %%
sys.path
# Out:
# ['C:\\Users\\skme2\\Downloads',
#  'C:\\Users\\skme2\\anaconda3\\python38.zip',
#  'C:\\Users\\skme2\\anaconda3\\DLLs',
#  'C:\\Users\\skme2\\anaconda3\\lib',
#  'C:\\Users\\skme2\\anaconda3',
#  '',
#  'C:\\Users\\skme2\\AppData\\Roaming\\Python\\Python38\\site-packages',
#  'C:\\Users\\skme2\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\skme2\\Downloads\\p1\\FSDS_NOV_deepCNNClassifier\\src',
#  'C:\\Users\\skme2\\anaconda3\\lib\\site-packages\\locket-0.2.1-py3.8.egg',
#  'C:\\Users\\skme2\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\skme2\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\skme2\\anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\skme2\\anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\skme2\\.ipython']

# %%
# datatime

# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2024, 8, 29, 8, 8, 54, 841263)

# %%
print(dir(datetime))
# Out:
# ['MAXYEAR', 'MINYEAR', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'date', 'datetime', 'datetime_CAPI', 'sys', 'time', 'timedelta', 'timezone', 'tzinfo']

# %%
print(dir(datetime.datetime))
# Out:
# ['__add__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__rsub__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', 'astimezone', 'combine', 'ctime', 'date', 'day', 'dst', 'fold', 'fromisocalendar', 'fromisoformat', 'fromordinal', 'fromtimestamp', 'hour', 'isocalendar', 'isoformat', 'isoweekday', 'max', 'microsecond', 'min', 'minute', 'month', 'now', 'replace', 'resolution', 'second', 'strftime', 'strptime', 'time', 'timestamp', 'timetuple', 'timetz', 'today', 'toordinal', 'tzinfo', 'tzname', 'utcfromtimestamp', 'utcnow', 'utcoffset', 'utctimetuple', 'weekday', 'year']

# %%
# Different ways of importaing modules

# %%
import math

# %%
import random

# %%
import sys

# %%
import math as m

# %%
m.factorial(5)
# Out:
# 120

# %%
from math import factorial

# %%
factorial(5)
# Out:
# 120

# %%
from math import *

# %%
# Custom Modules

# %%
__name__
# Out:
# '__main__'

# %%
import math

# %%
import custom_29_08 as myc
# Out:
# I am a custom 29 08 module
# Today is a good weather
# I am having some custom functionalites
# custom module 2908: custom_29_08

# %%
myc.greeting('ravi')
# Out:
# I am greeting you in the morning ravi

# %%
myc.custom_test("i am revising all the concepts")
# Out:
# i am messaging you

# %%
myc.area(5)
# Out:
# 31.400000000000002

# %%
import project_29_08
# Out:
# i am a main project
# I am greeting you in the morning ravi
# i am messaging you
# 31.400000000000002
# this is complete project
# final project 29_08: project_29_08

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 0CC1-C20F
#
#  Directory of C:\Users\skme2\Downloads
#
# 29-08-2024  08:36    <DIR>          .
# 28-08-2024  09:30    <DIR>          ..
# 29-08-2024  08:31    <DIR>          .ipynb_checkpoints
# 29-08-2024  08:36    <DIR>          __pycache__
# 01-06-2024  17:40               346 01_06_02.sql
# 01-06-2024  20:07               347 01_06_02_practice.sql
# 01-06-2024  16:43             8,550 01_06_window.sql
# 06-11-2023  11:20             2,633 01_11_sql_practice.sql
# 29-08-2024  08:36            18,503 01_modules_29_08.ipynb
# 03-05-2024  20:46         3,932,766 02_05_open_cv.ipynb
# 02-11-2022  15:49           410,816 0211resume.pdf
# 03-05-2024  20:45             4,167 03_05_cv2.ipynb
# 03-05-2024  19:04               576 03_05_open_cv.ipynb
# 04-06-2024  11:16           224,228 03_06_matplotlib_11_1230.ipynb
# 13-10-2023  15:25    <DIR>          03_10_4pm
# 13-10-2023  15:24        98,232,624 03_10_4pm.zip
# ...
