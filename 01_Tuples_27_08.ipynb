# %% [markdown]
# # Tuples:
# * It is similar to list(but generally used for only read only purposes)
# * It is a collection of elements which are ordered or sequenced
# * it is indexable and slicable
# * it is immutable in nature means we can not change elements inside a tuple.

# %%
tup = tuple()

# %%
type(tup)
# Out:
# tuple

# %%
t = ()

# %%
type(t)
# Out:
# tuple

# %%
f = (4,5,6,7,8,9,10,17,16,11,12)

# %%
type(f)
# Out:
# tuple

# %%
h = (12,23,14,10,2.3,5.6,4.1,8.9,True,5+6j,(1,5,6), [10,20,30], {4,8,9}, {"a":1, "b":2, "c":3})

# %%
h
# Out:
# (12,
#  23,
#  14,
#  10,
#  2.3,
#  5.6,
#  4.1,
#  8.9,
#  True,
#  (5+6j),
#  (1, 5, 6),
#  [10, 20, 30],
#  {4, 8, 9},
#  {'a': 1, 'b': 2, 'c': 3})

# %%
type(h)
# Out:
# tuple

# %%
a = (45)

# %%
type(a)
# Out:
# int

# %%
c = ("data")

# %%
type(c)
# Out:
# str

# %%
x = 10,

# %%
type(x)
# Out:
# tuple

# %%
q = "science",

# %%
type(q)
# Out:
# tuple

# %%
#Accessing of elements

# %%
f
# Out:
# (4, 5, 6, 7, 8, 9, 10, 17, 16, 11, 12)

# %%
f[0]
# Out:
# 4

# %%
f[1]
# Out:
# 5

# %%
f[-1]
# Out:
# 12

# %%
f[-3]
# Out:
# 16

# %%
len(f)
# Out:
# 11

# %%
f
# Out:
# (4, 5, 6, 7, 8, 9, 10, 17, 16, 11, 12)

# %%
f[1:4]
# Out:
# (5, 6, 7)

# %%
f[-3:]
# Out:
# (16, 11, 12)

# %%
f[-2:-5:-1]
# Out:
# (11, 16, 17)

# %%
f
# Out:
# (4, 5, 6, 7, 8, 9, 10, 17, 16, 11, 12)

# %%
f[::-1]
# Out:
# (12, 11, 16, 17, 10, 9, 8, 7, 6, 5, 4)

# %%
f
# Out:
# (4, 5, 6, 7, 8, 9, 10, 17, 16, 11, 12)

# %%
f[:-2]
# Out:
# (4, 5, 6, 7, 8, 9, 10, 17, 16)

# %%
f[0:-3]
# Out:
# (4, 5, 6, 7, 8, 9, 10, 17)

# %%
f[:]
# Out:
# (4, 5, 6, 7, 8, 9, 10, 17, 16, 11, 12)

# %%
# changing a tuple

# %%
f
# Out:
# (4, 5, 6, 7, 8, 9, 10, 17, 16, 11, 12)

# %%
f[1] = 500
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-5d9d3cf9fcf7> in <module>
# ----> 1 f[1] = 500
#
# TypeError: 'tuple' object does not support item assignment

# %%
lst = ['html', 'css', 'python', 'javascript', 'sql']

# %%
q = (90, 50, 100, lst ,82, 14)

# %%
lst
# Out:
# ['html', 'css', 'python', 'javascript', 'sql']

# %%
q
# Out:
# (90, 50, 100, ['html', 'css', 'python', 'javascript', 'sql'], 82, 14)

# %%
q[3][-2] = "java"

# %%
q
# Out:
# (90, 50, 100, ['html', 'css', 'python', 'java', 'sql'], 82, 14)

# %%
q
# Out:
# (90, 50, 100, ['html', 'css', 'python', 'java', 'sql'], 82, 14)

# %%
lst
# Out:
# ['html', 'css', 'python', 'java', 'sql']

# %%
# Tuples Operations

# %%
f
# Out:
# (4, 5, 6, 7, 8, 9, 10, 17, 16, 11, 12)

# %%
for i in f:
    print(i*2)
# Out:
# 8
# 10
# 12
# 14
# 16
# 18
# 20
# 34
# 32
# 22
# 24

# %%
# Concatinating Tuples

# %%
d = (1,2,3)

# %%
g = (4,5,6)

# %%
h = d + g

# %%
d
# Out:
# (1, 2, 3)

# %%
g
# Out:
# (4, 5, 6)

# %%
h
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
(5,)*3
# Out:
# (5, 5, 5)

# %%
# Tuple Deletion

# %%
f
# Out:
# (4, 5, 6, 7, 8, 9, 10, 17, 16, 11, 12)

# %%
f
# Out:
# (4, 5, 6, 7, 8, 9, 10, 17, 16, 11, 12)

# %%
del f[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-e4e89ab76919> in <module>
# ----> 1 del f[2]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
f
# Out:
# (4, 5, 6, 7, 8, 9, 10, 17, 16, 11, 12)

# %%
del f

# %%
f
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-a9fcd54b25e7> in <module>
# ----> 1 f
#
# NameError: name 'f' is not defined

# %%
#Tuple methods

# %%
v = (1,4,7,8,5,2,7,6,9,7,10)

# %%
v
# Out:
# (1, 4, 7, 8, 5, 2, 7, 6, 9, 7, 10)

# %%
print(v)
# Out:
# (1, 4, 7, 8, 5, 2, 7, 6, 9, 7, 10)

# %%
v.count(7)
# Out:
# 3

# %%
v.index(7)
# Out:
# 2

# %%
v.index(7,3)
# Out:
# 6

# %%
v
# Out:
# (1, 4, 7, 8, 5, 2, 7, 6, 9, 7, 10)

# %%
7 in v
# Out:
# True

# %%
140 not in v
# Out:
# True

# %%
150 in v
# Out:
# False

# %%
x = (4,5,6,8)

# %%
print(*x)
# Out:
# 4 5 6 8

# %%
s,d,f,g = x

# %%
s
# Out:
# 4

# %%
d
# Out:
# 5

# %%
f
# Out:
# 6

# %%
g
# Out:
# 8
